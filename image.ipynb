# %%
import matplotlib.pyplot as pl
import numpy as np

# %%
#khondan aks
data = np.array(plt.imread(r'C:\Users\Seyed\Downloads\jadid idk\sign2.jpg'))

# %%
a = np.array(plt.imread(r'C:\Users\Seyed\Downloads\jadid idk\sign2.jpg'))
a.shape
# Out:
# (360, 540, 3)

# %%
#taghirat dar akse khonde shode (baraye taghirat dar aks niyaz hast ke ba dastor ((np.array)) dar khate khondan vorodi az halat read only kharej beshim )
a[85:190, 175:375] =(177,1,22)

# %%
plt.imshow(a)

# %%
#greftan kanal range RGB ye pixel moshakhas
data[50, 300]
# Out:
# array([177,   1,  22], dtype=uint8)

# %%
#siyah sefid kardane aks

# %%
gray_img = a[:,:,0] // 3 + a[:,:,1] // 3 + a[:,:,2] // 3

# %%
plt.imshow(gray_img, cmap = 'gray')

# %%
gray_img.max()
# Out:
# np.uint8(253)
